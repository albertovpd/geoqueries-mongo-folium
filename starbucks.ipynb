# %% [markdown]
# # I'll take all airports of the world from this dataset

# %%
import pandas as pd

# %%
data = pd.read_csv ("input/starbucks.csv")

# %%
# https://www.kaggle.com/open-flights/airports-train-stations-and-ferry-terminals#airports-extended.csv

# %%
null_cols = data.isnull().sum()
drop_cols = list(null_cols[null_cols > 35000].index)
data_clean1 = data.drop(drop_cols, axis=1)
data.dropna()
# Out:
#            Brand  Store Number                           Store Name  \
# 0      Starbucks  47370-257954                        Meritxell, 96
# 11     Starbucks   1579-122101  HCT Abu Dhabi Women's College Block
# 12     Starbucks  32595-122105          Standard Chartered Building
# 20     Starbucks  32767-131566                      Shangri-La Souq
# 45     Starbucks  32640-131563                       Tawam Hospital
# ...          ...           ...                                  ...
# 25594  Starbucks  27082-246744                                Emart
# 25595  Starbucks  21401-212072                                  Rex
# 25596  Starbucks  24010-226985                             Panorama
# 25597  Starbucks  47608-253804                        Rosebank Mall
# 25599  Starbucks  47609-253286                       Mall of Africa
#
#       Ownership Type                                     Street Address  \
# 0           Licensed                                  Av. Meritxell, 96
# ...

# %% [markdown]
# ## Finding out the "real" name of columns to work it

# %%
col_names=[]
for e in data:
    col_names.append(e)
col_names
# Out:
# ['Brand',
#  'Store Number',
#  'Store Name',
#  'Ownership Type',
#  'Street Address',
#  'City',
#  'State/Province',
#  'Country',
#  'Postcode',
#  'Phone Number',
#  'Timezone',
#  'Longitude',
#  'Latitude']

# %%
starbucks=[]
for e in data["Store Name"]:
    starbucks.append(e)

# %%
star_long=[]
star_lat=[]
for e in data["Longitude"]:
    star_long.append(e)
for e in data["Latitude"]:
    star_lat.append(e)

# %% [markdown]
# I have some str-types that I must turn into float

# %%
def type_conversor(x):
    for e in x:
        e=float(e)
    return

# %%
type_conversor(star_long)
type_conversor(star_lat)

# %% [markdown]
# # I'll call this list from main.ipynb to find the closest airport to each office

# %%
starbucks
# %store starbucks
star_lat
# %store star_lat
star_long
# %store star_long
# Out:
# Stored 'starbucks' (list)
# Stored 'star_lat' (list)
# Stored 'star_long' (list)
